# %% [markdown]
# <a href="https://colab.research.google.com/github/JessicaWiijaya/COVID_19/blob/main/COVID19_day_wise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import pandas
import pandas as pd
# load dataset
from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
dataset = '/drive/My Drive/COVID19/day_wise.csv'

# %%
df = pd.read_csv(
    dataset)
df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
df.shape
# Out:
# (188, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    188 non-null    object
#  1   Confirmed               188 non-null    int64
#  2   Deaths                  188 non-null    int64
#  3   Recovered               188 non-null    int64
#  4   Active                  188 non-null    int64
#  5   New cases               188 non-null    int64
#  6   New deaths              188 non-null    int64
#  7   New recovered           188 non-null    int64
#  8   Deaths / 100 Cases      188 non-null    float64
#  9   Recovered / 100 Cases   188 non-null    float64
#  10  Deaths / 100 Recovered  188 non-null    float64
#  11  No. of countries        188 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 17.8+ KB

# %%
df.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02     188.000000
# mean   4.406960e+06  230770.760638  2.066001e+06  2.110188e+06   87771.021277
# std    4.757988e+06  217929.094183  2.627976e+06  1.969670e+06   75295.293255
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    1.121910e+05    3935.000000  6.044125e+04  5.864175e+04    5568.500000
# 50%    2.848733e+06  204190.000000  7.847840e+05  1.859759e+06   81114.000000
# 75%    7.422046e+06  418634.500000  3.416396e+06  3.587015e+06  131502.500000
# max    1.648048e+07  654036.000000  9.468087e+06  6.358362e+06  282756.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   188.000000     188.000000          188.000000             188.000000
# mean   3478.824468   50362.015957            4.860638              34.343936
# ...

# %%
Region = df.groupby(by='Date').sum()
Region
# Out:
#             Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# Date
# 2020-01-22        555      17         28      510          0           0
# 2020-01-23        654      18         30      606         99           1
# 2020-01-24        941      26         36      879        287           8
# 2020-01-25       1434      42         39     1353        493          16
# 2020-01-26       2118      56         52     2010        684          14
# ...               ...     ...        ...      ...        ...         ...
# 2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
#             New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Date
# ...

# %%
# df = df.drop(columns='Deaths')
df.drop(columns='Deaths', inplace=True) # menghapus kolom bernama 'Deaths'
df.head() # tampilkan 5 baris pertama
# Out:
#          Date  Confirmed  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555         28     510          0           0
# 1  2020-01-23        654         30     606         99           1
# 2  2020-01-24        941         36     879        287           8
# 3  2020-01-25       1434         39    1353        493          16
# 4  2020-01-26       2118         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# 2                   72.22                 9
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Confirmed', 'Recovered', 'Active', 'New cases', 'New deaths',
#        'New recovered', 'Deaths / 100 Cases', 'Recovered / 100 Cases',
#        'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                       object
# Confirmed                   int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# No. of countries            int64
# dtype: object

# %%
df.isna().values.any() #Mendeteksi keberadaan nilai yang kosong
# Out:
# False

# %%
df.drop_duplicates(inplace=True) # menghapus duplikasi data
df.shape
# Out:
# (188, 11)

# %%
df.describe()
# Out:
#           Confirmed     Recovered        Active      New cases   New deaths  \
# count  1.880000e+02  1.880000e+02  1.880000e+02     188.000000   188.000000
# mean   4.406960e+06  2.066001e+06  2.110188e+06   87771.021277  3478.824468
# std    4.757988e+06  2.627976e+06  1.969670e+06   75295.293255  2537.735652
# min    5.550000e+02  2.800000e+01  5.100000e+02       0.000000     0.000000
# 25%    1.121910e+05  6.044125e+04  5.864175e+04    5568.500000   250.750000
# 50%    2.848733e+06  7.847840e+05  1.859759e+06   81114.000000  4116.000000
# 75%    7.422046e+06  3.416396e+06  3.587015e+06  131502.500000  5346.000000
# max    1.648048e+07  9.468087e+06  6.358362e+06  282756.000000  9966.000000
#
#        New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count     188.000000          188.000000             188.000000
# mean    50362.015957            4.860638              34.343936
# std     56090.892479            1.579541              16.206159
# ...

# %%
df.corr()
# Out:
# <ipython-input-55-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         Confirmed  Recovered    Active  New cases  New deaths  \
# Confirmed                1.000000   0.990165  0.986543   0.961473    0.555479
# Recovered                0.990165   1.000000  0.953981   0.936576    0.476217
# Active                   0.986543   0.953981  1.000000   0.967578    0.637241
# New cases                0.961473   0.936576  0.967578   1.000000    0.721846
# New deaths               0.555479   0.476217  0.637241   0.721846    1.000000
# New recovered            0.944875   0.935754  0.931824   0.928570    0.555759
# Deaths / 100 Cases       0.221469   0.096131  0.364250   0.367629    0.774790
# Recovered / 100 Cases    0.720283   0.711328  0.711695   0.670914    0.328203
# ...

# %%
import matplotlib.pyplot as plt # visualisasi data
import seaborn as sns # visualisasi data

# output dari visualisasi data akan diarahkan ke notebook
# %matplotlib inline

# %%
sns.heatmap(data= df.corr())
# Out:
# <ipython-input-57-aec1994f8f9b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data= df.corr())
# <Axes: >

# %%
df['Recovered'].value_counts()
# Out:
# 28         1
# 2509981    1
# 1900768    1
# 2008541    1
# 2062802    1
#           ..
# 119804     1
# 128508     1
# 136800     1
# 146261     1
# 9468087    1
# Name: Recovered, Length: 188, dtype: int64

# %%
df['Date'].value_counts()
# Out:
# 2020-01-22    1
# 2020-05-30    1
# 2020-05-21    1
# 2020-05-22    1
# 2020-05-23    1
#              ..
# 2020-03-26    1
# 2020-03-27    1
# 2020-03-28    1
# 2020-03-29    1
# 2020-07-27    1
# Name: Date, Length: 188, dtype: int64

# %%
df['Date'].value_counts().plot.bar()
plt.tight_layout()
plt.show()

# %%
sns.countplot(data= df, x='Date')
plt.tight_layout()
# sns.countplot?

# %%
df['Date'].value_counts().plot.pie(autopct='%1.1f%%', labels=None, legend=True
                                        )
plt.tight_layout()
# Out:
# <ipython-input-66-bf1c2be969a7>:3: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
fig,ax = plt.subplots(nrows=2, ncols=2, figsize=(8,8))

df['Confirmed'].plot.line(ax=ax[0][0])
ax[0][0].set_title('Confirmed')

df['Confirmed'].plot.line(ax=ax[0][1])
ax[0][1].set_title('Confirmed')

df.Recovered.plot.line(ax=ax[1][0])
ax[1][0].set_title('Recovered')

df.Recovered.plot.line(ax=ax[1][1])
ax[1][1].set_title('Recovered')
# Out:
# Text(0.5, 1.0, 'Recovered')

# %%
df.plot()
plt.tight_layout()

# %%
df.hist(figsize=(6,6), bins=10) #hist = histogram, bins=lebar datanya
plt.tight_layout()

# %%
df.boxplot()
plt.tight_layout()

# %%
df.boxplot(by="Date", figsize=(8,8))
plt.tight_layout()

# %%
sns.scatterplot(x='Active', y='Confirmed', data= df, hue='Date')
plt.tight_layout()
# Out:
# <ipython-input-74-da8d8f258c96>:2: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
sns.pairplot( df, hue='Date', markers='+')
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split # Iris dataset
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %%
X = df.drop(columns='Date')
X.head() # tampilkan 5 baris pertama
# Out:
#    Confirmed  Recovered  Active  New cases  New deaths  New recovered  \
# 0        555         28     510          0           0              0
# 1        654         30     606         99           1              2
# 2        941         36     879        287           8              6
# 3       1434         39    1353        493          16              3
# 4       2118         52    2010        684          14             13
#
#    Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 0                3.06                   5.05                   60.71
# 1                2.75                   4.59                   60.00
# 2                2.76                   3.83                   72.22
# 3                2.93                   2.72                  107.69
# 4                2.64                   2.46                  107.69
#
#    No. of countries
# 0                 6
# 1                 8
# 2                 9
# 3                11
# 4                13

# %%
y = df['Date']
y.head() # tampilkan 5 baris pertama
# Out:
# 0    2020-01-22
# 1    2020-01-23
# 2    2020-01-24
# 3    2020-01-25
# 4    2020-01-26
# Name: Date, dtype: object

# %%
# membagi dataset ke dalam training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=10)

print('training dataset')
print(X_train.shape)
print(y_train.shape)
print()
print('testing dataset:')
print(X_test.shape)
print(y_test.shape)
# Out:
# training dataset
# (112, 10)
# (112,)
#
# testing dataset:
# (76, 10)
# (76,)
